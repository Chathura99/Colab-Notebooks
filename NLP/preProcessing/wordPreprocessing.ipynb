# %%
import nltk

# %% [markdown]
# **Tokenizer methods**

# %%
text ="Hello, I'm Chathura Manohara. I'm studying University of Colombo(UCSC)."

# %%
tokenizer = nltk.tokenize.WhitespaceTokenizer();
print(tokenizer.tokenize(text))
# Out:
# ['Hello,', "I'm", 'Chathura', 'Manohara.', "I'm", 'studying', 'University', 'of', 'Colombo(UCSC).']

# %%
tokenizer = nltk.tokenize.TreebankWordTokenizer();
print(tokenizer.tokenize(text))
# Out:
# ['Hello', ',', 'I', "'m", 'Chathura', 'Manohara.', 'I', "'m", 'studying', 'University', 'of', 'Colombo', '(', 'UCSC', ')', '.']

# %%
tokenizer = nltk.tokenize.WordPunctTokenizer();
print(tokenizer.tokenize(text))
# Out:
# ['Hello', ',', 'I', "'", 'm', 'Chathura', 'Manohara', '.', 'I', "'", 'm', 'studying', 'University', 'of', 'Colombo', '(', 'UCSC', ').']

# %% [markdown]
# **The WordNetLemmatizer is a tool used to convert words to their base form or lemma**

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
lemmatizer = nltk.stem.WordNetLemmatizer()

words = ["running", "runner", "ran", "runs"]
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]

print(lemmatized_words)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# ['running', 'runner', 'ran', 'run']
